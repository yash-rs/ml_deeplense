# %% [markdown]
# ### Visualising the data, etc.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.load("../data/processed/all_train_data.npy")
y = np.load("../data/processed/all_train_labels.npy")

# %%
print(X.shape, y.shape)
# Out:
# (30000, 1, 150, 150) (30000,)

# %% [markdown]
# #### So, X is a 3-dim numpy array with 30000 (150 x 150) images and y is an array of corresponsing labels

# %%
sample_image = X[28000, 0, :,:]
plt.imshow(sample_image, cmap="gray")
plt.colorbar()
plt.axis("off")
plt.show()
